# %%
import pandas as pd

# %%
df=pd.read_csv("Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
x=df.iloc[:,3:]

# %%
x
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Unclustered Data")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.scatter(x["Annual Income (k$)"],x["Spending Score (1-100)"])

# %%
from sklearn.cluster import KMeans,AgglomerativeClustering

# %%
SSE=[]
for i in range(1,16):
    km=KMeans(n_clusters=i)
    km.fit_predict(x)
    SSE.append(km.inertia_)
# Out:
# C:\Users\Mayuri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Mayuri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Mayuri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
SSE
# Out:
# [269981.28,
#  181363.595959596,
#  106348.37306211119,
#  73679.78903948836,
#  44448.45544793371,
#  37233.81451071001,
#  30241.34361793659,
#  25311.633152958155,
#  21826.936303231654,
#  19710.0302716608,
#  17887.99232082517,
#  16434.444470307975,
#  14314.980233818469,
#  12928.618410755911,
#  12105.56699134199]

# %%
plt.title("Elbow Method")
plt.xlabel("No. of Clusters")
plt.ylabel("Inertia Value")
plt.xticks(range(1,16))
plt.plot(range(1,16),SSE,marker=".",color="blue")
plt.grid()

# %%
from sklearn.metrics import silhouette_score
Silh=[]
for i in range(2,16):
    km=KMeans(n_clusters=i)
    labels=km.fit_predict(x)
    score=silhouette_score(x,labels)
    Silh.append(score);
# Out:
# C:\Users\Mayuri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Mayuri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Mayuri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.title("Silhouette Method")
plt.xlabel("No. of Clusters")
plt.ylabel("Inertia Value")
plt.xticks(range(2,16))
plt.plot(range(2,16),Silh,color="blue")
plt.grid()

# %%
km=KMeans(n_clusters=5)

# %%
kmean=km.fit_predict(x)
# Out:
# C:\Users\Mayuri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.title("nclustered Data using KMeans")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.scatter(x["Annual Income (k$)"],x["Spending Score (1-100)"],c=kmean)

# %%
ac=AgglomerativeClustering(n_clusters=5)
agl=ac.fit_predict(x)

# %%
plt.title("clustered Data using AgglorometiveClustering")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.scatter(x["Annual Income (k$)"],x["Spending Score (1-100)"],c=agl)
